# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import datetime

# %% [markdown]
# # Import retail data

# %%
retail_df = pd.read_csv("/home/aleksei/Desktop/projects/MLOPs-boootcamp-project/data/OnlineRetail.csv", encoding='unicode_escape')

# %%
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
retail_df['InvoiceDate'] = (pd.to_datetime(retail_df['InvoiceDate']).
                            dt.strftime('%Y-%m-%d'))

# %%
data = (retail_df
        .groupby(['InvoiceDate', 'StockCode'])
        .sum()
        .reset_index()
        .sort_values(['StockCode', 'InvoiceDate'], ascending=True)
        [['InvoiceDate', 'StockCode', 'Quantity']])

# %%
data.pivot_table(columns='StockCode', index='InvoiceDate', values='Quantity')
# Out:
# StockCode    10002  10080  10120  10123C  10123G  10124A  10124G  10125  \
# InvoiceDate
# 2010-12-01    60.0    NaN    NaN     NaN     NaN     NaN     NaN    2.0
# 2010-12-02     1.0    NaN    NaN     NaN     NaN     NaN     5.0    NaN
# 2010-12-03     8.0    NaN    3.0     1.0     NaN     NaN     NaN    NaN
# 2010-12-05     1.0    NaN    NaN     NaN     NaN     NaN     NaN    NaN
# 2010-12-06    25.0    NaN    NaN     NaN     NaN     4.0     NaN    3.0
# ...            ...    ...    ...     ...     ...     ...     ...    ...
# 2011-12-05     NaN    NaN    NaN     NaN     NaN     NaN     NaN    NaN
# 2011-12-06     NaN    NaN    NaN     NaN     NaN     NaN     NaN    NaN
# 2011-12-07     NaN    NaN    NaN     NaN     NaN     NaN     NaN    NaN
# 2011-12-08     NaN    NaN    NaN     NaN     NaN     NaN     NaN    NaN
# 2011-12-09     NaN    NaN    NaN     NaN     NaN     NaN     NaN   20.0
#
# StockCode    10133  10134  ...      M  PADS  POST   S  gift_0001_10  \
# InvoiceDate                ...
# 2010-12-01     5.0    NaN  ...    2.0   NaN   5.0 NaN           NaN
# 2010-12-02     NaN    NaN  ...    NaN   NaN   1.0 NaN           NaN
# 2010-12-03     1.0    NaN  ...    3.0   NaN  15.0 NaN           NaN
# 2010-12-05    14.0    NaN  ...   56.0   NaN  23.0 NaN           NaN
# 2010-12-06     2.0    NaN  ...   20.0   NaN   1.0 NaN           NaN
# ...            ...    ...  ...    ...   ...   ...  ..           ...
# 2011-12-05     NaN    NaN  ...  802.0   NaN  15.0 NaN           NaN
# 2011-12-06     NaN    NaN  ...    5.0   NaN  24.0 NaN           NaN
# 2011-12-07     NaN    NaN  ...   -2.0   NaN  21.0 NaN           NaN
# 2011-12-08     NaN    NaN  ...    3.0   NaN  12.0 NaN           1.0
# 2011-12-09     NaN    NaN  ...   -1.0   NaN   9.0 NaN           NaN
#
# StockCode    gift_0001_20  gift_0001_30  gift_0001_40  gift_0001_50   m
# InvoiceDate
# 2010-12-01            NaN           NaN           NaN           NaN NaN
# 2010-12-02            NaN           NaN           NaN           NaN NaN
# 2010-12-03            NaN           NaN           NaN           NaN NaN
# 2010-12-05            NaN           NaN           NaN           NaN NaN
# 2010-12-06            NaN           NaN           NaN           NaN NaN
# ...                   ...           ...           ...           ...  ..
# 2011-12-05            NaN           NaN           NaN           NaN NaN
# 2011-12-06            NaN           NaN           NaN           NaN NaN
# 2011-12-07            NaN           NaN           NaN           NaN NaN
# 2011-12-08            NaN           NaN           NaN           NaN NaN
# 2011-12-09            NaN           NaN           NaN           NaN NaN
#
# [305 rows x 4070 columns]
